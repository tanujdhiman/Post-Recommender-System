# %% [markdown]
# # Recommendation System

# %% [markdown]
# In this recommendation system I have used Kaggle dataset named Post Recommendation System Here is the link of that : https://www.kaggle.com/vatsalparsaniya/post-pecommendation
#
# It will consume a user_id and check the history or like or vote he has given to post and check other users simliarities and then recommend posts.
#
# Here we go::::::::::::

# %%
#importing relevant libraries

import pandas as pd
import numpy as np
import re

# %%
#Datasets Importing 
#post_data consists of post details like post_id, title, category
#user_data consists of user's information
#view_data consists of which user view which post

post_data = pd.read_csv(r'post_data.csv')
user_data = pd.read_csv(r'user_data.csv')
view_data = pd.read_csv(r'view_data.csv')

# %%
post_data.head()
# Out:
#                                                title     category    post_id
# 0                        Find A Quick Way To GRAPHIC      graphic   10260109
# 1                                  How To Sell CRAFT        Craft   39550285
# 2  POLITICS An Incredibly Easy Method That Works ...     politics  935118791
# 3                  5 Brilliant Ways To Use POLITICAL    political  151805043
# 4   How To Make Your MATHEMATICS Look Amazing In ...  Mathematics  995833095

# %%
user_data.head()
# Out:
#                     user_id  first_name  last_name  gender  \
# 0  5eece14efc13ae6609000000      Milena   Lacelett  Female
# 1  5eece14efc13ae6609000001       Nolan    Satcher    Male
# 2  5eece14efc13ae6609000002     Eveleen  Cotterell  Female
# 3  5eece14efc13ae6609000003     Petrina       Berr  Female
# 4  5eece14efc13ae6609000004  Saunderson  Duquesnay    Male
#
#                                               avatar             city  \
# 0  https://robohash.org/quisidomnis.png?size=50x5...  Blagoveshchensk
# 1  https://robohash.org/dignissimosrepudiandaedol...           Wufeng
# 2  https://robohash.org/remomnissuscipit.png?size...     Barra Bonita
# 3  https://robohash.org/estquasconsectetur.png?si...       San Angelo
# 4  https://robohash.org/nullaaest.png?size=50x50&...         Olszówka
#
#        academics
# 0  undergraduate
# 1  undergraduate
# 2  undergraduate
# 3  undergraduate
# 4       graduate

# %%
view_data.head()
# Out:
#                     user_id    post_id           time_stamp
# 0  5eece14ffc13ae660900008b  136781766  01/01/2019 01:30 PM
# 1  5eece14efc13ae660900003c   43094523  01/01/2019 01:33 PM
# 2  5eece14efc13ae6609000025   42428071  01/01/2019 01:43 PM
# 3  5eece14ffc13ae66090001d4   76472880  01/01/2019 01:54 PM
# 4  5eece14ffc13ae66090000ac  202721843  01/01/2019 02:00 PM

# %%
#Making Recommendation system is not a supervised learning right that consist of label but it is 
# unsupervised learning so we have to add likes or make it valuable that means the user rate it valuable
# in terms of rating like out of 5 okay
# I add up it.

dataframe = pd.DataFrame(view_data)

# %%
dataframe["Valuable"] = np.random.randint(1, 6, len(dataframe))

# %%
#this is our data right now.
dataframe
# Out:
#                         user_id    post_id           time_stamp  Valuable
# 0      5eece14ffc13ae660900008b  136781766  01/01/2019 01:30 PM         3
# 1      5eece14efc13ae660900003c   43094523  01/01/2019 01:33 PM         3
# 2      5eece14efc13ae6609000025   42428071  01/01/2019 01:43 PM         3
# 3      5eece14ffc13ae66090001d4   76472880  01/01/2019 01:54 PM         3
# 4      5eece14ffc13ae66090000ac  202721843  01/01/2019 02:00 PM         2
# ...                         ...        ...                  ...       ...
# 71795  5eece14ffc13ae660900018c  615389604  12/31/2019 12:37 AM         5
# 71796  5eece14ffc13ae660900010c  348689108  12/31/2019 12:50 PM         2
# 71797  5eece14ffc13ae6609000190  619052165  12/31/2019 12:51 AM         5
# 71798  5eece14efc13ae6609000067  426384418  12/31/2019 12:51 PM         1
# 71799  5eece14ffc13ae6609000110  165390871  12/31/2019 12:54 AM         5
#
# [71800 rows x 4 columns]

# %%
# in this cell we are merging view data and the dataframe I have made of post data. in this post id is common.

df = pd.merge(dataframe, post_data ,on='post_id')
df.tail()
# Out:
#                         user_id    post_id           time_stamp  Valuable  \
# 71795  5eece14ffc13ae66090000c3  810223923  08/28/2019 06:32 PM         1
# 71796  5eece14efc13ae6609000073  810223923  09/15/2019 06:58 PM         5
# 71797  5eece14ffc13ae660900017d  810223923  10/31/2019 09:50 PM         2
# 71798  5eece14ffc13ae66090000e3  810223923  12/04/2019 03:56 PM         1
# 71799  5eece14ffc13ae6609000135  810223923  12/20/2019 09:54 AM         5
#
#                                                    title category
# 71795   7 and a Half Very Simple Things You Can Do To...  graphic
# 71796   7 and a Half Very Simple Things You Can Do To...  graphic
# 71797   7 and a Half Very Simple Things You Can Do To...  graphic
# 71798   7 and a Half Very Simple Things You Can Do To...  graphic
# 71799   7 and a Half Very Simple Things You Can Do To...  graphic

# %%
#drop the irrevelent features i.e category is important but not for this. and also time_stamp is not 
#important right now.
data = df.drop(['time_stamp', 'category'], axis=1)

# %%
data.tail()
# Out:
#                         user_id    post_id  Valuable  \
# 71795  5eece14ffc13ae66090000c3  810223923         1
# 71796  5eece14efc13ae6609000073  810223923         5
# 71797  5eece14ffc13ae660900017d  810223923         2
# 71798  5eece14ffc13ae66090000e3  810223923         1
# 71799  5eece14ffc13ae6609000135  810223923         5
#
#                                                    title
# 71795   7 and a Half Very Simple Things You Can Do To...
# 71796   7 and a Half Very Simple Things You Can Do To...
# 71797   7 and a Half Very Simple Things You Can Do To...
# 71798   7 and a Half Very Simple Things You Can Do To...
# 71799   7 and a Half Very Simple Things You Can Do To...

# %%
# In this first we have to make a column here that consists of total ratings a title or a post have. 
#like 10 Funny ART Quotes has 15 votes given by users.

combine_post_rating = data.dropna(axis = 0, subset = ['title'])

post_ratingCount = (combine_post_rating.
     groupby(by = ['title'])['Valuable'].
     count().
     reset_index().
     rename(columns = {'Valuable': 'totalValuableCount'})
     [['title', 'totalValuableCount']]
    )
post_ratingCount.head()
# Out:
#                        title  totalValuableCount
# 0        10 Funny ART Quotes                  15
# 1    10 Funny BANKING Quotes                  10
# 2   10 Funny BUSINESS Quotes                  13
# 3      10 Funny CRAFT Quotes                   9
# 4      10 Funny DANCE Quotes                  19

# %%
#Merge it into our main dataset 
rating_with_totalValuableCount = combine_post_rating.merge(post_ratingCount, left_on = 'title', right_on = 'title', how = 'left')
rating_with_totalValuableCount.tail()
# Out:
#                         user_id    post_id  Valuable  \
# 71795  5eece14ffc13ae66090000c3  810223923         1
# 71796  5eece14efc13ae6609000073  810223923         5
# 71797  5eece14ffc13ae660900017d  810223923         2
# 71798  5eece14ffc13ae66090000e3  810223923         1
# 71799  5eece14ffc13ae6609000135  810223923         5
#
#                                                    title  totalValuableCount
# 71795   7 and a Half Very Simple Things You Can Do To...                   5
# 71796   7 and a Half Very Simple Things You Can Do To...                   5
# 71797   7 and a Half Very Simple Things You Can Do To...                   5
# 71798   7 and a Half Very Simple Things You Can Do To...                   5
# 71799   7 and a Half Very Simple Things You Can Do To...                   5

# %%
#It is just how to see data desciption and stuff.
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(post_ratingCount['totalValuableCount'].describe())
# Out:
# count   6000.000
# mean      11.967
# std        3.449
# min        2.000
# 25%       10.000
# 50%       12.000
# 75%       14.000
# max       24.000
# Name: totalValuableCount, dtype: float64

# %%
print(post_ratingCount['totalValuableCount'].quantile(np.arange(.9, 1, .01)))
# Out:
# 0.900   17.000
# 0.910   17.000
# 0.920   17.000
# 0.930   17.000
# 0.940   18.000
# 0.950   18.000
# 0.960   18.000
# 0.970   19.000
# 0.980   19.020
# 0.990   21.000
# Name: totalValuableCount, dtype: float64

# %%
#we have to fix a threshold here that machine will recommend post to user that have votes greater than
# the threshold values
popularity_threshold = 13
rating_popular_post = rating_with_totalValuableCount.query('totalValuableCount >= @popularity_threshold')
rating_popular_post.tail()
# Out:
#                         user_id   post_id  Valuable  \
# 71697  5eece14ffc13ae66090001bb  36975738         4
# 71698  5eece14ffc13ae660900012d  36975738         3
# 71699  5eece14efc13ae660900006c  36975738         5
# 71700  5eece14ffc13ae660900007e  36975738         5
# 71701  5eece14efc13ae6609000048  36975738         2
#
#                                                    title  totalValuableCount
# 71697   I Don't Want To Spend This Much Time On MUSIC...                  13
# 71698   I Don't Want To Spend This Much Time On MUSIC...                  13
# 71699   I Don't Want To Spend This Much Time On MUSIC...                  13
# 71700   I Don't Want To Spend This Much Time On MUSIC...                  13
# 71701   I Don't Want To Spend This Much Time On MUSIC...                  13

# %%
rating_popular_post.shape
# Out:
# (38292, 5)

# %%
user_data.head()
# Out:
#                     user_id  first_name  last_name  gender  \
# 0  5eece14efc13ae6609000000      Milena   Lacelett  Female
# 1  5eece14efc13ae6609000001       Nolan    Satcher    Male
# 2  5eece14efc13ae6609000002     Eveleen  Cotterell  Female
# 3  5eece14efc13ae6609000003     Petrina       Berr  Female
# 4  5eece14efc13ae6609000004  Saunderson  Duquesnay    Male
#
#                                               avatar             city  \
# 0  https://robohash.org/quisidomnis.png?size=50x5...  Blagoveshchensk
# 1  https://robohash.org/dignissimosrepudiandaedol...           Wufeng
# 2  https://robohash.org/remomnissuscipit.png?size...     Barra Bonita
# 3  https://robohash.org/estquasconsectetur.png?si...       San Angelo
# 4  https://robohash.org/nullaaest.png?size=50x50&...         Olszówka
#
#        academics
# 0  undergraduate
# 1  undergraduate
# 2  undergraduate
# 3  undergraduate
# 4       graduate

# %%
len(user_data.city.unique())
# Out:
# 491

# %% [markdown]
# Making model from here.
# we have to make a data matrix like indexes are titles and columns are user id and target is how valuable or how much likes it have.

# %% [markdown]
# Use here cosine similiarity to find the simliarity between user and other users.

# %%
from scipy.sparse import csr_matrix
rating_popular_post = rating_popular_post.drop_duplicates(['user_id', 'title'])
rating_popular_post_pivot = rating_popular_post.pivot(index = 'title', columns = 'user_id', values = 'Valuable').fillna(0)
rating_popular_post_matrix = csr_matrix(rating_popular_post_pivot.values)

from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(rating_popular_post_matrix)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %%
rating_popular_post_pivot.shape[0]
# Out:
# 2513

# %%
rating_popular_post_pivot
# Out:
# user_id                                             5eece14efc13ae6609000000  \
# title
#  10 Funny ART Quotes                                                   0.000
#  10 Funny BUSINESS Quotes                                              0.000
#  10 Funny DANCE Quotes                                                 0.000
#  10 Funny DRAWING Quotes                                               0.000
#  10 Funny GRAPHIC Quotes                                               0.000
# ...                                                                      ...
# ZOOLOGY Your Way To Success                                            0.000
# ZOOLOGY: An Incredibly Easy Method That Works F...                     0.000
# ZOOLOGY: Do You Really Need It? This Will Help ...                     0.000
# ZOOLOGY: The Samurai Way                                               0.000
# ZOOLOGY? It's Easy If You Do It Smart                                  0.000
#
# user_id                                             5eece14efc13ae6609000001  \
# title
#  10 Funny ART Quotes                                                   0.000
#  10 Funny BUSINESS Quotes                                              0.000
#  10 Funny DANCE Quotes                                                 0.000
#  10 Funny DRAWING Quotes                                               0.000
#  10 Funny GRAPHIC Quotes                                               0.000
# ...                                                                      ...
# ZOOLOGY Your Way To Success                                            0.000
# ZOOLOGY: An Incredibly Easy Method That Works F...                     0.000
# ZOOLOGY: Do You Really Need It? This Will Help ...                     0.000
# ZOOLOGY: The Samurai Way                                               0.000
# ZOOLOGY? It's Easy If You Do It Smart                                  0.000
#
# user_id                                             5eece14efc13ae6609000002  \
# title
#  10 Funny ART Quotes                                                   0.000
#  10 Funny BUSINESS Quotes                                              0.000
#  10 Funny DANCE Quotes                                                 0.000
#  10 Funny DRAWING Quotes                                               0.000
#  10 Funny GRAPHIC Quotes                                               0.000
# ...                                                                      ...
# ZOOLOGY Your Way To Success                                            0.000
# ZOOLOGY: An Incredibly Easy Method That Works F...                     0.000
# ZOOLOGY: Do You Really Need It? This Will Help ...                     0.000
# ZOOLOGY: The Samurai Way                                               0.000
# ZOOLOGY? It's Easy If You Do It Smart                                  0.000
#
# user_id                                             5eece14efc13ae6609000003  \
# title
#  10 Funny ART Quotes                                                   0.000
#  10 Funny BUSINESS Quotes                                              0.000
#  10 Funny DANCE Quotes                                                 0.000
#  10 Funny DRAWING Quotes                                               0.000
#  10 Funny GRAPHIC Quotes                                               0.000
# ...                                                                      ...
# ZOOLOGY Your Way To Success                                            0.000
# ZOOLOGY: An Incredibly Easy Method That Works F...                     0.000
# ZOOLOGY: Do You Really Need It? This Will Help ...                     0.000
# ZOOLOGY: The Samurai Way                                               0.000
# ZOOLOGY? It's Easy If You Do It Smart                                  0.000
#
# user_id                                             5eece14ffc13ae66090001f2  \
# title
#  10 Funny ART Quotes                                                   0.000
#  10 Funny BUSINESS Quotes                                              0.000
#  10 Funny DANCE Quotes                                                 0.000
#  10 Funny DRAWING Quotes                                               0.000
#  10 Funny GRAPHIC Quotes                                               0.000
# ...                                                                      ...
# ZOOLOGY Your Way To Success                                            0.000
# ZOOLOGY: An Incredibly Easy Method That Works F...                     0.000
# ZOOLOGY: Do You Really Need It? This Will Help ...                     0.000
# ZOOLOGY: The Samurai Way                                               0.000
# ZOOLOGY? It's Easy If You Do It Smart                                  0.000
#
# user_id                                             5eece14ffc13ae66090001f3
# title
#  10 Funny ART Quotes                                                   0.000
#  10 Funny BUSINESS Quotes                                              0.000
#  10 Funny DANCE Quotes                                                 0.000
#  10 Funny DRAWING Quotes                                               0.000
#  10 Funny GRAPHIC Quotes                                               0.000
# ...                                                                      ...
# ZOOLOGY Your Way To Success                                            0.000
# ZOOLOGY: An Incredibly Easy Method That Works F...                     0.000
# ZOOLOGY: Do You Really Need It? This Will Help ...                     0.000
# ZOOLOGY: The Samurai Way                                               0.000
# ZOOLOGY? It's Easy If You Do It Smart                                  0.000
#
# [2513 rows x 495 columns]

# %% [markdown]
# Choose a random users and recommend it a title of post by looking their cosine simliarity scores

# %%
query_index = np.random.choice(rating_popular_post_pivot.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(rating_popular_post_pivot.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 186

# %%
# this is our name of user 3 and title he has seen or vote it and our task is to recommend it similiar
#post
rating_popular_post_pivot.index[query_index]
# Out:
# ' 3 Mistakes In DANCE That Make You Look Dumb'

# %%
#Here we go
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(rating_popular_post_pivot.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}:'.format(i, rating_popular_post_pivot.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for  3 Mistakes In DANCE That Make You Look Dumb:
#
# 1:  Never Changing GRAPHIC Will Eventually Destroy You, with distance of 0.7032371623363501:
# 2:  10 Tips That Will Make You Influential In CRAFT, with distance of 0.7267841024811379:
# 3:  Fall In Love With OPERATING SYSTEM, with distance of 0.7402270129541558:
# 4:  How To Save Money with SCIENCE?, with distance of 0.7407620763173937:
# 5:  Sick And Tired Of Doing BUSINESS The Old Way? Read This, with distance of 0.7452830038796782:
